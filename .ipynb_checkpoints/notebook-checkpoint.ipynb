# %%
# import modules and libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import train dataset
df_train = pd.read_csv('Train.csv')
df_train.head(10)
# Out:
#             ID  Year_of_Birth Education_Level Marital_Status  \
# 0  ID_4A9AR6FQ           1955      Graduation       Divorced
# 1  ID_X28T3VEK           1958      Graduation       Together
# 2  ID_AWXARH57           1962      Graduation         Single
# 3  ID_FQVZHE81           1979        2n Cycle         Single
# 4  ID_QVLWGPRN           1959      Graduation        Married
# 5  ID_3S3HRGH6           1960          Master        Married
# 6  ID_KJQ9B2LE           1953      Graduation         Single
# 7  ID_6O0NBZXD           1974      Graduation       Together
# 8  ID_M3QFT8WO           1966      Graduation       Together
# 9  ID_745JV5PY           1975      Graduation        Married
#
#    Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 0            77504.4                   1                   1    22-06-2014
# 1            56784.0                   0                   1    01-08-2013
# ...

# %%
# import test dataset
df_test = pd.read_csv('Test.csv')
df_test.head(10)
# Out:
#             ID  Year_of_Birth Education_Level Marital_Status  \
# 0  ID_ZPMABNVX           1954      Graduation         Single
# 1  ID_WFE91NAA           1961      Graduation          Widow
# 2  ID_JV11RBRK           1973           Basic        Married
# 3  ID_6B7SVKY9           1970      Graduation       Together
# 4  ID_GOVUZ545           1959      Graduation       Together
# 5  ID_A3SFW973           1959      Graduation       Together
# 6  ID_HERGG0GD           1961          Master       Together
# 7  ID_S36UV4BY           1958      Graduation        Married
# 8  ID_9E10P1ZZ           1984      Graduation         Single
# 9  ID_2840OCS5           1983      Graduation        Married
#
#    Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 0            48556.8                   0                   1    11-01-2013
# 1            57499.2                   0                   1    22-11-2012
# ...

# %% [markdown]
# TRAIN DATA

# %%
#get the shape of the train data
df_train.shape
# Out:
# (1568, 27)

# %%
#get the statistical description of the float columns of the train data
df_train.describe()
# Out:
#        Year_of_Birth  Disposable_Income  No_of_Kids_in_home  \
# count    1568.000000        1552.000000         1568.000000
# mean     1970.073342       62381.186598            0.460459
# std        11.920781       32089.169563            0.540361
# min      1900.000000        2076.000000            0.000000
# 25%      1960.000000       41612.400000            0.000000
# 50%      1971.000000       60964.200000            0.000000
# 75%      1979.000000       81493.200000            1.000000
# max      1997.000000      799999.200000            2.000000
#
#        No_of_Teen_in_home      Recency  Discounted_Purchases  WebPurchases  \
# count         1568.000000  1568.000000           1568.000000   1568.000000
# mean             0.497449    55.408801              2.292730      4.001276
# std              0.544151    28.788037              1.937544      2.773748
# min              0.000000     7.000000              0.000000      0.000000
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1568 non-null   object
#  1   Year_of_Birth            1568 non-null   int64
#  2   Education_Level          1568 non-null   object
#  3   Marital_Status           1568 non-null   object
#  4   Disposable_Income        1552 non-null   float64
#  5   No_of_Kids_in_home       1568 non-null   int64
#  6   No_of_Teen_in_home       1568 non-null   int64
#  7   Date_Customer            1568 non-null   object
#  8   Recency                  1568 non-null   int64
#  9   Discounted_Purchases     1568 non-null   int64
#  10  WebPurchases             1568 non-null   int64
#  11  CatalogPurchases         1568 non-null   int64
#  12  StorePurchases           1568 non-null   int64
#  13  Amount_on_Wines          1568 non-null   int64
# ...

# %%
df_train.isnull().sum()
# Out:
# ID                          0
# Year_of_Birth               0
# Education_Level             0
# Marital_Status              0
# Disposable_Income          16
# No_of_Kids_in_home          0
# No_of_Teen_in_home          0
# Date_Customer               0
# Recency                     0
# Discounted_Purchases        0
# WebPurchases                0
# CatalogPurchases            0
# StorePurchases              0
# Amount_on_Wines             0
# Amount_on_Fruits            0
# Amount_on_MeatProducts      0
# Amount_on_FishProducts      0
# Amount_on_SweetProducts     0
# Amount_on_GoldProds         0
# WebVisitsMonth              0
# Cmp3Accepted                0
# Cmp4Accepted                0
# Cmp5Accepted                0
# Cmp1Accepted                0
# Cmp2Accepted                0
# Any_Complain                0
# Response                    0
# dtype: int64

# %% [markdown]
# TEST DATA

# %%
#get the shape of the test data
df_test.shape
# Out:
# (672, 26)

# %%
#get the statistical description of the float columns of the test data
df_test.describe()
# Out:
#        Year_of_Birth  Disposable_Income  No_of_Kids_in_home  \
# count     672.000000         664.000000          672.000000
# mean     1969.181548       63434.170482            0.406250
# std        12.116416       25276.585476            0.532259
# min      1894.000000        5313.600000            0.000000
# 25%      1960.000000       44219.700000            0.000000
# 50%      1970.000000       64007.400000            0.000000
# 75%      1978.000000       83466.300000            1.000000
# max      1997.000000      194876.400000            2.000000
#
#        No_of_Teen_in_home     Recency  Discounted_Purchases  WebPurchases  \
# count          672.000000  672.000000            672.000000    672.000000
# mean             0.526786   57.744048              2.400298      4.279762
# std              0.545293   29.321893              1.919125      2.782585
# min              0.000000    7.000000              0.000000      0.000000
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       672 non-null    object
#  1   Year_of_Birth            672 non-null    int64
#  2   Education_Level          672 non-null    object
#  3   Marital_Status           672 non-null    object
#  4   Disposable_Income        664 non-null    float64
#  5   No_of_Kids_in_home       672 non-null    int64
#  6   No_of_Teen_in_home       672 non-null    int64
#  7   Date_Customer            672 non-null    object
#  8   Recency                  672 non-null    int64
#  9   Discounted_Purchases     672 non-null    int64
#  10  WebPurchases             672 non-null    int64
#  11  CatalogPurchases         672 non-null    int64
#  12  StorePurchases           672 non-null    int64
#  13  Amount_on_Wines          672 non-null    int64
# ...

# %%
df_test.isnull().sum()
# Out:
# ID                         0
# Year_of_Birth              0
# Education_Level            0
# Marital_Status             0
# Disposable_Income          8
# No_of_Kids_in_home         0
# No_of_Teen_in_home         0
# Date_Customer              0
# Recency                    0
# Discounted_Purchases       0
# WebPurchases               0
# CatalogPurchases           0
# StorePurchases             0
# Amount_on_Wines            0
# Amount_on_Fruits           0
# Amount_on_MeatProducts     0
# Amount_on_FishProducts     0
# Amount_on_SweetProducts    0
# Amount_on_GoldProds        0
# WebVisitsMonth             0
# Cmp3Accepted               0
# Cmp4Accepted               0
# Cmp5Accepted               0
# Cmp1Accepted               0
# Cmp2Accepted               0
# Any_Complain               0
# dtype: int64

# %% [markdown]
# We will remove the rows with null values because they are less than 2 percent of both datasets

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
# distribution of the train year of birth column
fig = plt.figure(figsize=(20,10))
sns.histplot(data = df_train, x = 'Year_of_Birth', kde = True)
plt.title("Distribution of `the year of birth")
# Out:
# Text(0.5, 1.0, 'Distribution of `the year of birth')

# %%
df_train['Year_of_Birth'].unique()
# Out:
# array([1955, 1958, 1962, 1979, 1959, 1960, 1953, 1974, 1966, 1975, 1989,
#        1956, 1976, 1970, 1965, 1977, 1952, 1981, 1951, 1995, 1973, 1972,
#        1971, 1988, 1984, 1990, 1986, 1969, 1900, 1967, 1987, 1992, 1968,
#        1963, 1957, 1944, 1961, 1950, 1954, 1982, 1991, 1947, 1985, 1978,
#        1980, 1964, 1983, 1949, 1993, 1948, 1994, 1946, 1942, 1945, 1996,
#        1997], dtype=int64)

# %% [markdown]
# 1900 is an outlier so we remove it

# %%
df_train[df_train['Year_of_Birth']== 1900]
# Out:
#              ID  Year_of_Birth Education_Level Marital_Status  \
# 54  ID_MNOMSWCS           1900             PhD       Together
#
#     Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 54           100238.4                   0                   0    26-09-2013
#
#     Recency  Discounted_Purchases  ...  Amount_on_SweetProducts  \
# 54       43                     1  ...                       64
#
#     Amount_on_GoldProds  WebVisitsMonth  Cmp3Accepted  Cmp4Accepted  \
# 54                  224               1             0             0
#
#     Cmp5Accepted  Cmp1Accepted  Cmp2Accepted  Any_Complain  Response
# 54             1             0             0             0         0
#
# [1 rows x 27 columns]

# %%
df_train = df_train.loc[df_train['Year_of_Birth'] != 1900]

# %%
df_train[df_train['Year_of_Birth']== 1900]
# Out:
# Empty DataFrame
# Columns: [ID, Year_of_Birth, Education_Level, Marital_Status, Disposable_Income, No_of_Kids_in_home, No_of_Teen_in_home, Date_Customer, Recency, Discounted_Purchases, WebPurchases, CatalogPurchases, StorePurchases, Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts, Amount_on_GoldProds, WebVisitsMonth, Cmp3Accepted, Cmp4Accepted, Cmp5Accepted, Cmp1Accepted, Cmp2Accepted, Any_Complain, Response]
# Index: []
#
# [0 rows x 27 columns]

# %%
# distribution of the train year of birth column
fig = plt.figure(figsize=(20,10))
sns.histplot(data = df_train, x = 'Year_of_Birth', kde = True)
plt.title("Distribution of the year of birth")
# Out:
# Text(0.5, 1.0, 'Distribution of the year of birth')

# %% [markdown]
# Now, we have a normal distribution in the year of birth column

# %%
# distribution of the test year of birth column
fig = plt.figure(figsize=(20,10))
sns.histplot(data = df_test, x = 'Year_of_Birth', kde = True)
plt.title("Distribution of the year of birth")
# Out:
# Text(0.5, 1.0, 'Distribution of the year of birth')

# %%
df_test['Year_of_Birth'].unique()
# Out:
# array([1954, 1961, 1973, 1970, 1959, 1958, 1984, 1983, 1952, 1980, 1969,
#        1953, 1956, 1971, 1968, 1978, 1976, 1963, 1975, 1982, 1962, 1960,
#        1955, 1964, 1945, 1972, 1986, 1987, 1947, 1985, 1989, 1967, 1965,
#        1992, 1957, 1974, 1977, 1981, 1991, 1966, 1993, 1979, 1951, 1950,
#        1988, 1901, 1997, 1990, 1949, 1948, 1894, 1994, 1941, 1944],
#       dtype=int64)

# %% [markdown]
# Years 1901 and 1894 are the outliers

# %%
df_test[(df_test['Year_of_Birth']== 1901) | (df_test['Year_of_Birth'] == 1894)]
# Out:
#               ID  Year_of_Birth Education_Level Marital_Status  \
# 217  ID_B93L67NF           1901        2n Cycle       Divorced
# 316  ID_010PXSMV           1894        2n Cycle         Single
#
#      Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 217            43968.0                   1                   0    26-09-2013
# 316            72218.4                   0                   1    17-05-2014
#
#      Recency  Discounted_Purchases  ...  Amount_on_FishProducts  \
# 217      106                     1  ...                       7
# 316       30                     1  ...                       7
#
#      Amount_on_SweetProducts  Amount_on_GoldProds  WebVisitsMonth  \
# 217                        4                   25               5
# 316                        0                    2               4
#
#      Cmp3Accepted  Cmp4Accepted  Cmp5Accepted  Cmp1Accepted  Cmp2Accepted  \
# ...

# %%
df_test = df_test.loc[df_test['Year_of_Birth'] != 1901] 
df_test = df_test.loc[df_test['Year_of_Birth'] != 1894]

# %%
# distribution of the test year of birth column (test data)
fig = plt.figure(figsize=(20,10))
sns.histplot(data = df_test, x = 'Year_of_Birth', kde = True)
plt.title("Distribution of the year of birth")
# Out:
# Text(0.5, 1.0, 'Distribution of the year of birth')

# %%
X_train = df.drop
